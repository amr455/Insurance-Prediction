# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
data = pd.read_csv('insurance.csv')
x=data.drop('charges' ,axis=1)
y=data['charges']

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
y.head()
# Out:
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# Name: charges, dtype: float64

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
sns.histplot(data["age"],kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.boxplot(data["children"])
# Out:
# <Axes: ylabel='children'>

# %%
sns.boxplot(data["bmi"], orient='v', color='skyblue')
# Out:
# <Axes: ylabel='bmi'>

# %%
data['bmi'] = np.log1p(data['bmi'])
sns.boxplot(data["bmi"], orient='h', color='skyblue')
# Out:
# <Axes: xlabel='bmi'>

# %%
data['charges'] = np.log1p(data['charges'])
sns.boxplot(data["charges"], orient='h', color='skyblue')
# Out:
# <Axes: xlabel='charges'>

# %%
plt.figure(figsize=(16, 8))

# Select the columns for which you want to check for outliers
columns_to_check = [
'bmi', 'children', 'age', 'charges'
]

# Create subplots for each column
for i, column in enumerate(columns_to_check, start=1):
    plt.subplot(6, 6, i)
    sns.boxplot(data[column], orient='v', color='skyblue')
    plt.title(column)

# Adjust the layout
plt.tight_layout()
plt.show()

# %%
sns.pairplot(data)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['sex']=le.fit_transform(data['sex'])

# %%
data['smoker']=le.fit_transform(data['smoker'])
data['region']=le.fit_transform(data['region'])

# %%
data.head()
# Out:
#    age  sex       bmi  children  smoker  region      charges
# 0   19    0  3.363842         0       1       3  16884.92400
# 1   18    1  3.548755         1       0       2   1725.55230
# 2   28    1  3.526361         3       0       2   4449.46200
# 3   33    1  3.165686         0       0       1  21984.47061
# 4   32    1  3.397189         0       0       1   3866.85520

# %%
x=data.drop('charges' ,axis=1)
y=data['charges']

# %%
x.head()
# Out:
#    age  sex       bmi  children  smoker  region
# 0   19    0  3.363842         0       1       3
# 1   18    1  3.548755         1       0       2
# 2   28    1  3.526361         3       0       2
# 3   33    1  3.165686         0       0       1
# 4   32    1  3.397189         0       0       1

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x=scaler.fit_transform(data)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
print(y_pred)
# Out:
# [ 9.11559754  8.57038808 10.28643377  9.13808077 10.42677397  8.42007836
#   7.6583875   9.5618093   8.22513492  9.2365384   9.81247998  8.88982144
#   8.28106903 10.73969827 10.79291177 10.69656273  9.19033032 10.66827732
#   9.01603904  9.9885326   8.53328227  8.91496223  7.13672105  7.92154323
#   9.31349126  9.29880291  9.44506374  9.84191808  9.18161584  7.03218869
#   9.66965089  9.37954492  7.61162096  8.64724387  7.97421896  8.9158893
#   7.862797    8.90092353 10.08115926 10.56385779  8.45293133  7.88014975
#   9.36521622  9.40310656  8.49515196  9.42018208  8.18334953  8.38768842
#  10.6484089   8.40384645  9.53879513  7.4503332  10.25687783  7.44420523
#   9.26815877 10.13991578  8.20141047 10.56481778  9.38001065  9.26538565
#   9.53834464  8.46687559 10.2378965   8.98945192 10.04527206  8.32715594
#   9.79496125 10.16561414  8.18734679  7.42868785  8.71287041  9.14974128
#   9.02216339  8.75448823  8.87538099  8.49495511  8.48630506  9.34618347
# ...

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test, y_pred)

r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 8.757533452289382e-29
# R-squared: 1.0

# %%
# Some notation from the metrics

from sklearn import metrics
# Model Evaluation
print("R^2:",metrics.r2_score(y_test, y_pred))
print("Adjusted R^2:",1 - (1-metrics.r2_score(y_test, y_pred))*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1))
print("MAE:",metrics.mean_absolute_error(y_test, y_pred))
print("MSE:",metrics.mean_squared_error(y_test, y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R^2: 1.0
# Adjusted R^2: 1.0
# MAE: 7.178337526382355e-15
# MSE: 8.757533452289382e-29
# RMSE: 9.358169400202895e-15

# %%
sns.regplot(x=y_test,y=y_pred,ci=None,color ='red')
# Out:
# <Axes: xlabel='charges'>

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
# Plot the distribution of y_test (actual values) in blue
plt.hist(y_test, bins=20, alpha=0.5, color='blue', label='Actual Values')

# Plot the distribution of y_pred (predicted values) in red
plt.hist(y_pred, bins=20, alpha=0.5, color='red', label='Predicted Values')

plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Distribution of Actual vs. Predicted Values")
plt.legend()

plt.show()
